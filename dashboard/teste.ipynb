# %%
import pandas as pd

df_brasileirao = pd.read_excel('./data/brasileirao.xlsx')

mapping = {
    'Internacional':'Internacional',
    'Cruzeiro':'Cruzeiro',
    'Vitória':'EC Vitória',
    'Fluminense':'Fluminense',
    'Vasco':'Vasco da Gama',
    'Corinthians':'Corinthians',
    'São Paulo':'São Paulo',
    'Athletico/PR':'Athletico-PR',
    'Atlético/GO':'Atlético-GO',
    'Criciúma':'Criciúma EC',
    'Grêmio':'Grêmio',
    'Atlético/MG':'Atlético-MG',
    'Bahia':'EC Bahia',
    'Flamengo':'Flamengo',
    'Botafogo':'Botafogo',
    'Palmeiras':'Palmeiras',
    'RB Bragantino':'RB Bragantino',
    'Fortaleza':'Fortaleza',
    'Cuiabá':'Cuiabá-MT',
    'Juventude':'Juventude',
}

df_brasileirao['Mandante'] = df_brasileirao['Mandante'].map(mapping)
df_brasileirao['Visitante'] = df_brasileirao['Visitante'].map(mapping)

# %%
df_brasileirao[df_brasileirao['Rod.'] == 8]
# Out:
#     Rod.       Data      Hora       Mandante      Visitante          Estádio  \
# 70     8 2024-05-25  16:00:00  Internacional      São Paulo        Beira-Rio
# 71     8 2024-05-25  16:00:00       Cruzeiro      Cuiabá-MT         Mineirão
# 72     8 2024-05-25  16:00:00       EC Bahia      Fortaleza       Fonte Nova
# 73     8 2024-05-25  16:00:00       Flamengo         Grêmio         Maracanã
# 74     8 2024-05-25  16:00:00       Botafogo     Fluminense    Nilton Santos
# 75     8 2024-05-25  16:00:00      Palmeiras  Vasco da Gama   Allianz Parque
# 76     8 2024-05-25  16:00:00  RB Bragantino    Atlético-MG  Nabi Abi Chedid
# 77     8 2024-05-25  16:00:00   Athletico-PR    Criciúma EC      Ligga Arena
# 78     8 2024-05-25  16:00:00    Atlético-GO    Corinthians  Antônio Accioly
# 79     8 2024-05-25  16:00:00      Juventude     EC Vitória   Alfredo Jaconi
#
#             Cidade
# 70    Porto Alegre
# 71  Belo Horizonte
# 72        Salvador
# 73  Rio de Janeiro
# 74  Rio de Janeiro
# ...
